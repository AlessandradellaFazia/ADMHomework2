# %% [markdown]
# # [RQ1] What’s the operation users repeat more on average within a session?
# ##### Produce a plot that shows the average number of times users perform each operation (view/removefromchart etc etc).

# %% [markdown]
# For this purpose, we display the monthly average and the overall average of the months of October, November, December, January, Febrary, March, April.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from datetime import timedelta
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set()

# %%
#dataset used
filenames = ['2019-Oct.csv', '2019-Nov.csv','2019-Dec.csv','2020-Jan.csv','2020-Feb.csv','2020-Mar.csv','2020-Apr.csv']

# %%
months = ['October', 'November','December','January','Febrary','March','April']
cols = ['midnightblue', 'goldenrod','red', 'forestgreen', 'dodgerblue','rebeccapurple','orange']

# %%
dataframes = [pd.read_csv(file,usecols=["event_type","user_id","user_session"]) for file in filenames]

# %% [markdown]
# Let's look october and november data as example:

# %%
dataframes[0].head()
# Out:
#   event_type    user_id                          user_session
# 0       view  541312140  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1       view  554748717  9333dfbd-b87a-4708-9857-6336556b0fcc
# 2       view  519107250  566511c2-e2e3-422b-b695-cf8e6e792ca8
# 3       view  550050854  7c90fc70-0e80-4590-96f3-13c02c18c713
# 4       view  535871217  c6bd7419-2748-4c56-95b4-8cec9ff8b80d

# %%
dataframes[1].head()
# Out:
#   event_type    user_id                          user_session
# 0       view  520088904  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 1       view  530496790  8e5f4f83-366c-4f70-860e-ca7417414283
# 2       view  561587266  755422e7-9040-477b-9bd2-6a6e8fd97387
# 3       view  518085591  3bfb58cd-7892-48cc-8020-2f17e6de6e7f
# 4       view  558856683  313628f1-68b8-460d-84f6-cec7a8796ef2

# %%
def event_type_into_datasets(dataframes):
    #print for each dataset the list of event tipe
    for j in range(len(dataframes)):
        print(months[j],dataframes[j].event_type.unique())

# %% [markdown]
# Let's look what types of events there are in every dataset:

# %%
event_type_into_datasets(dataframes)
# Out:
# October ['view' 'purchase' 'cart']
# November ['view' 'cart' 'purchase']
# December ['view' 'purchase' 'cart']
# January ['view' 'cart' 'purchase']
# Febrary ['view' 'cart' 'purchase']
# March ['view' 'purchase' 'cart']
# April ['view' 'cart' 'purchase']

# %%
#counts the number of occurence of each event for each session
def count_event_types(dataframes):   
    results = [df.groupby(['user_session', 'event_type']).agg(events_count = ('event_type','count')) for df in dataframes]
    return results

# %% [markdown]
# Now, for each session, we see how many times each operation are performed.<br>
# Below we see a piece of October as example:

# %%
counts = count_event_types(dataframes)
counts[0].head(5)
# Out:
#                                                  events_count
# user_session                         event_type
# 00000042-3e3f-42f9-810d-f3d264139c50 view                   2
# 00000056-a206-40dd-b174-a072550fa38c view                   8
# 00000083-8816-4d58-a9b8-f52f54186edc cart                   1
#                                      purchase               1
#                                      view                  16

# %%
#overall count
all_months = pd.concat(counts)

# %%
all_months_mean = all_months.groupby('event_type').agg(avg_event_type = ('events_count','mean') )

# %%
#caluclate the average number of occurence of each event for each session for each month 
def mean_count_event_types(dataframes):    
    counts = count_event_types(dataframes)
    mean_counts =[c.groupby('event_type').agg(avg_event_type = ('events_count','mean') ) for c in counts]
    return mean_counts

# %%
mean_counts = mean_count_event_types(dataframes)

# %% [markdown]
# Below we see for each month the average times user perform each type of operation.

# %%
for m in mean_counts:
    print (m.head())
# Out:
#             avg_event_type
# event_type
# cart              1.616679
# purchase          1.179949
# view              4.412088
#             avg_event_type
# event_type
# cart              1.737422
# purchase          1.185880
# view              4.616633
#             avg_event_type
# event_type
# cart              1.711502
# purchase          1.197981
# view              4.043304
#             avg_event_type
# event_type
# cart              1.711213
# purchase          1.208526
# view              3.815562
#             avg_event_type
# event_type
# cart              1.738196
# purchase          1.591866
# view              3.876134
#             avg_event_type
# event_type
# cart              1.811467
# purchase          1.207023
# view              4.150490
#             avg_event_type
# event_type
# cart              1.789873
# purchase          1.229963
# view              5.358778

# %%
def plot(dataframe):
    i = 0
    fig=plt.figure(figsize=(18,22))
    ax1 = fig.add_subplot(4,2,i+1)
    plot=sns.barplot(x=mean_counts[i].index,y='avg_event_type',data=mean_counts[i],ax=ax1,color=cols[i])
    plt.ylabel('Average in ' + months[i])
    plt.title('Average number of operations in ' + months[i],size = 12)
    i = i + 1
    ax2 = fig.add_subplot(4,2,i+1)
    plot=sns.barplot(x=mean_counts[i].index,y='avg_event_type',data=mean_counts[i],ax=ax2,color=cols[i])
    plt.ylabel('Average in ' + months[i])
    plt.title('Average number of operations in ' + months[i],size = 12)
    i = i + 1
    ax3 = fig.add_subplot(4,2,i+1)
    plot=sns.barplot(x=mean_counts[i].index,y='avg_event_type',data=mean_counts[i],ax=ax3,color=cols[i])
    plt.ylabel('Average in ' + months[i])
    plt.title('Average number of operations in ' + months[i],size = 12)
    i = i + 1
    ax4 = fig.add_subplot(4,2,i+1)
    plot=sns.barplot(x=mean_counts[i].index,y='avg_event_type',data=mean_counts[i],ax=ax4,color=cols[i])
    plt.ylabel('Average in ' + months[i])
    plt.title('Average number of operations in ' + months[i],size = 12)
    i = i + 1
    ax5 = fig.add_subplot(4,2,i+1)
    plot=sns.barplot(x=mean_counts[i].index,y='avg_event_type',data=mean_counts[i],ax=ax5,color=cols[i])
    plt.ylabel('Average in ' + months[i])
    plt.title('Average number of operations in ' + months[i],size = 12)
    i = i + 1
    ax6 = fig.add_subplot(4,2,i+1)
    plot=sns.barplot(x=mean_counts[i].index,y='avg_event_type',data=mean_counts[i],ax=ax6,color=cols[i])
    plt.ylabel('Average in ' + months[i])
    plt.title('Average number of operations in ' + months[i],size = 12)
    i = i +1 
    ax7 = fig.add_subplot(4,2,i+1)
    plot=sns.barplot(x=mean_counts[i].index,y='avg_event_type',data=mean_counts[i],ax=ax7,color=cols[i])
    plt.ylabel('Average in ' + months[i])
    plt.title('Average number of operations in ' + months[i],size = 12)

# %%
def plot_mean_count_event_types_all_months(all_months_mean):
    plt.figure(figsize=(9,6))
    plt.bar(x = all_months_mean.index, height= all_months_mean['avg_event_type'],color = 'crimson')        
    plt.grid( linestyle='-.', zorder = 0) 
    plt.title('Average number of times users performs each operation in a session in ' + ', '.join(months), size = 18)
    plt.xlabel('Event type',size = 14)
    plt.show()

# %%
plot(mean_counts)

# %%
plot_mean_count_event_types_all_months(all_months_mean)

# %% [markdown]
# # [RQ 1.2] How many times, on average, a user views a product before adding it to the cart?

# %% [markdown]
# For each user and for each product we count how many **views** there are before a **cart**.<br>
# Then, we calculate the averange.

# %%
datasets = [pd.read_csv(file, usecols=["event_type","user_id","product_id"])for file in filenames]

# %% [markdown]
# First of all, we only look at the views and cart event:

# %%
def only_view_and_cart(datasets):
    new_ds = [d[d.event_type.isin(['view','cart'])] for d in datasets]
    return new_ds

# %%
datasets = only_view_and_cart(datasets)

# %% [markdown]
# We only take the user-product pairs whose user actually adds the product to the cart after seeing it.

# %%
#take only the user-product pairs where product are added to the cart by the user
def only_cart_user_prod(datasets):
    new_sets = []
    for d in datasets:
        cart = d[d.event_type=='cart'].drop_duplicates()
        cart = cart.drop('event_type',axis=1)
        new_d = pd.merge(d,cart,how='left', on = ["user_id","product_id"])
        new_sets.append(new_d)
    return new_sets

# %%
datasets = only_cart_user_prod(datasets)
datasets[0].head()
# Out:
#   event_type  product_id    user_id
# 0       view    44600062  541312140
# 1       view     3900821  554748717
# 2       view    17200506  519107250
# 3       view     1307067  550050854
# 4       view     1004237  535871217

# %%
#compute how many view there are before a cart for each product for each user
def views_before_cart(datasets):
    views_before_cart_datasets = []
    for ds in datasets:
        views_before_cart_datasets.append(ds.groupby(['user_id','product_id','event_type'],sort=False)\
        .agg(views_before_cart=('event_type','count'))\
        .groupby(['user_id','product_id']).nth(0) )
    return views_before_cart_datasets

# %%
views_before_cart = views_before_cart(datasets)

# %% [markdown]
# Then, we calculate for each user and for each product he added to cart, how many views the user has made before adding it to the cart.<br>
# let's see what happened for the month of November:

# %%
views_before_cart[1].head(10)
# Out:
#                       views_before_cart
# user_id   product_id
# 422073359 31501013                    1
# 436701163 1004856                     1
# 442818338 1004856                     1
# 450284033 1004766                     1
# 454621403 1004249                     2
# 464783634 10301494                    1
# 482114459 3900003                     3
#           3900815                     2
#           3900934                     1
# 482871459 12710875                    1

# %%
def avg_views_before_cart(views_before_cart_datasets):
    for d in views_before_cart_datasets:
        views = [d.reset_index().drop(columns=['user_id','product_id'])]
    tot_views = pd.concat(views)
    return round(tot_views.mean(),2)

# %% [markdown]
# In the end, we consider all the months and we calculate the average number of views:

# %%
avg_views_before_cart(views_before_cart)[0]
# Out:
# 1.76

# %% [markdown]
# # [RQ 1.3] What’s the probability that products added once to the cart are effectively bought?
#
# We want to know the ratio between the number of times products has been bought on the number of times it has been added to the cart.<br>

# %%
frames = [pd.read_csv(file,usecols=["event_type","product_id"],index_col='event_type') for file in filenames]

# %%
frames = [f[f.index.isin(['purchase','cart'])] for f in frames]

# %% [markdown]
# We see the products for October dataset as example:

# %%
frames[0]
# Out:
#             product_id
# event_type
# purchase       1004856
# purchase       1002532
# cart           5100816
# purchase       5100816
# purchase      13800054
# ...                ...
# purchase      47500017
# purchase       1003306
# cart           1004240
# purchase       1004240
# purchase       4804056
#
# [1669365 rows x 1 columns]

# %%
def only_cart_product(frames):
    new_frames = []
    for f in frames:
        cart_products = f[f.index=='cart']['product_id'] #products that have been added to cart 
        f[f.product_id.isin(cart_products)]
        new_frames.append(f)
    return new_frames

# %% [markdown]
# For answer, we first get all and only the products that have been added to the cart.
#
# Then we count how many times they are been added to cart and how many times they are been bought.
#
# Finally, we see the ratio between them.

# %%
frames = only_cart_product(frames)

# %%
all_months = pd.concat(frames)

# %%
(all_months.index == 'purchase').sum() / (all_months.index == 'cart').sum()
# Out:
# 0.3583133528439244

# %% [markdown]
# # [RQ 1.4] What’s the average time an item stays in the cart before being removed?
#
# We measure, for each product, the time it stays in a cart (of a specific user).<br>
# For do this, we calculate the time interval between when a product is added to the cart and when it is bought.<br>
# Then, we calculate the average time over all the products.
#
# First, we select only the columns:
# - user_id
# - event_time
# - product_id
# - event_type
#
# and the events:
# 1. cart
# 2. purchase

# %%
dfs = [pd.read_csv(f, usecols=['user_id','event_time','product_id','event_type']) for f in filenames]

# %%
def only_cart_purchase(dfs):
    only_cart_purch_dfs = [ df[df.event_type.isin(['cart','purchase'])] for df in dfs]
    return only_cart_purch_dfs

# %%
cart_purchase_dfs = only_cart_purchase(dfs)

# %%
def time_btw_purchase_cart(framelist):
    delta = []
    for df in framelist:
        for key, frame in df.groupby(['user_id','product_id']):
            for i in range(1, len(frame),2):        
                if ((frame['event_type'].iloc[i] == 'purchase') and (frame['event_type'].iloc[i-1] == 'cart')):
                    delta.append(pd.to_datetime(frame['event_time'].iloc[i])  - pd.to_datetime(frame['event_time'].iloc[i-1]))
    return delta

# %%
time_delta = time_btw_purchase_cart(cart_purchase_dfs)

# %%
mean_time = sum(time_delta, timedelta()) / len(time_delta)

# %%
mean_time
# Out:
# Timedelta('0 days 00:14:17.659231')

# %%
minutes = mean_time.seconds//60
seconds = mean_time.seconds - minutes*60
print("%02d:%02d" % (minutes,seconds),'minutes')
# Out:
# 14:17 minutes

# %% [markdown]
# # [RQ1.5] How much time passes on average between the first view time and a purchase/addition to cart?

# %% [markdown]
# To answer we find for each user for each product:<br>
# the time in which the user saw a specific product for the first time and the time in which he bought it.<br>
# The we calculate the difference between this two time.<br>
# Finally, we calculate the average over all time intervals.

# %%
df = dfs[0]
df.head()
# Out:
#                 event_time event_type  product_id    user_id
# 0  2019-10-01 00:00:00 UTC       view    44600062  541312140
# 1  2019-10-01 00:00:00 UTC       view     3900821  554748717
# 2  2019-10-01 00:00:01 UTC       view    17200506  519107250
# 3  2019-10-01 00:00:01 UTC       view     1307067  550050854
# 4  2019-10-01 00:00:04 UTC       view     1004237  535871217

# %% [markdown]
# To do this, first we group our data based on the user, the product and the type of event,<br>
# where for each user and product, the first group collects the views, the second group collects the other types of events (cart or purchase).<br>
# Since we are interested in the average measure of user behavior, for each pair user-product, we only look at the first time the user view the product and the relative first time he bought it (or added to cart), ignoring the events in which a user re-acquires the same product.<br>
# Let's have a look below for the user 555480250 as example, we see that some products were simply displayed while the product 3700777 was viewed and added to the cart, so we calculate the difference between these two events.

# %%
df[df.user_id==555480250].groupby(['user_id','product_id','event_type'],sort=False).first()
# Out:
#                                               event_time
# user_id   product_id event_type
# 555480250 3700778    view        2019-10-01 04:13:04 UTC
#           3700787    view        2019-10-01 04:14:35 UTC
#           3700829    view        2019-10-01 04:17:23 UTC
#           3700777    view        2019-10-01 04:28:18 UTC
#                      cart        2019-10-01 04:28:27 UTC

# %% [markdown]
# Then we locate the cart event (or purchase event) and we associate with its view:

# %%
view = df[df.user_id==555480250].groupby(['user_id','product_id','event_type'],sort=False).first()\
.groupby(['user_id','product_id'],sort=False).nth(0)
cart = df[df.user_id==555480250].groupby(['user_id','product_id','event_type'],sort=False).first()\
.groupby(['user_id','product_id'],sort=False).nth(1)
view_and_cart = pd.merge(cart, view, how='left',on= ['user_id','product_id'])
view_and_cart
# Out:
#                                  event_time_x             event_time_y
# user_id   product_id
# 555480250 3700777     2019-10-01 04:28:27 UTC  2019-10-01 04:28:18 UTC

# %% [markdown]
# **event_time_x** is the time when the user add to cart the product.<br>
# **event_time_y** is the time when the user view to cart the product.

# %% [markdown]
# Finally, we compute the difference between the two event time.

# %%
view_and_cart['delta time'] = pd.to_datetime(view_and_cart['event_time_x']) - pd.to_datetime(view_and_cart['event_time_y'])
view_and_cart
# Out:
#                                  event_time_x             event_time_y  \
# user_id   product_id
# 555480250 3700777     2019-10-01 04:28:27 UTC  2019-10-01 04:28:18 UTC
#
#                      delta time
# user_id   product_id
# 555480250 3700777      00:00:09

# %% [markdown]
# Now let's do that for the entire dataset:

# %%
first_events_list = [df.groupby(['user_id','product_id','event_type'],sort=False).first() for df in dfs]

# %%
first_view_list = [fe.groupby(['user_id','product_id'],sort=False).nth(0) for fe in first_events_list]

# %%
first_cart_list = [fc.groupby(['user_id','product_id'],sort=False).nth(1) for fc in first_events_list]

# %%
time_btw_view_and_cart_list =[ pd.merge(cart, view, how='left',on= ['user_id','product_id']) 
                             for cart,view in zip(first_cart_list,first_view_list)]

# %%
def add_deltatime_column(dataframe_list):
    dataframe_result_list = []
    for frame in dataframe_list:
        frame['delta time'] = pd.to_datetime(frame['event_time_x']) - pd.to_datetime(frame['event_time_y'])
        dataframe_result_list.append(frame)
    return dataframe_result_list

# %%
deltatime_dataframes = add_deltatime_column(time_btw_view_and_cart_list)

# %% [markdown]
# Below we see for example the data for October.<br>
# For each user and for each product (purchased by the user) we collect the instant in which the user saw the product for the first time and the time in which he added it to the cart or bought it.<br>
# - **event_time_x** is the time of purchase (or add to cart).
# - **event_time_y** is the time of view.
# - **delta time** is the difference between them.

# %%
deltatime_dataframes[0].head()
# Out:
#                                  event_time_x             event_time_y  \
# user_id   product_id
# 543272936 1004856     2019-10-01 00:02:14 UTC  2019-10-01 00:01:46 UTC
# 551377651 1002532     2019-10-01 00:04:37 UTC  2019-10-01 00:02:47 UTC
# 550121407 5100816     2019-10-01 00:05:14 UTC  2019-10-01 00:04:47 UTC
# 514591159 5100816     2019-10-01 00:06:02 UTC  2019-10-01 00:04:02 UTC
# 555332717 13800054    2019-10-01 00:07:07 UTC  2019-10-01 00:06:00 UTC
#
#                      delta time
# user_id   product_id
# 543272936 1004856      00:00:28
# 551377651 1002532      00:01:50
# 550121407 5100816      00:00:27
# 514591159 5100816      00:02:00
# 555332717 13800054     00:01:07

# %%
def calculate_mean_deltatime(dataframe_list):
    all_months_frame = pd.concat(dataframe_list)
    return all_months_frame['delta time'].mean()

# %% [markdown]
# Now, we calculate the mean value of all the **delta time** values:

# %%
calculate_mean_deltatime(deltatime_dataframes)
# Out:
# Timedelta('0 days 20:48:00.105892')

# %% [markdown]
# We see a value of 20 hours and 48 minutes.
#
# It may seem a quite high value, but let's take a look at October and its largest **delta time** value.

# %%
deltatime_dataframes[0].nlargest(1,'delta time')
# Out:
#                                  event_time_x             event_time_y  \
# user_id   product_id
# 552651881 1004250     2019-10-31 21:03:01 UTC  2019-10-01 06:32:54 UTC
#
#                            delta time
# user_id   product_id
# 552651881 1004250    30 days 14:30:07

# %% [markdown]
# Now we check the **user** and **product** found in the original dataframe and see how actually 30 days have passed between the first time the user saw the product and the first action (between cart or purchase).

# %%
oct_frame = dfs[0]

# %%
oct_frame[(oct_frame['user_id']==552651881) & (oct_frame['product_id']== 1004250)]
# Out:
#                        event_time event_type  product_id    user_id
# 228902    2019-10-01 06:32:54 UTC       view     1004250  552651881
# 229056    2019-10-01 06:33:04 UTC       view     1004250  552651881
# 42421059  2019-10-31 21:02:54 UTC       view     1004250  552651881
# 42421095  2019-10-31 21:03:01 UTC       cart     1004250  552651881
# 42421261  2019-10-31 21:03:33 UTC   purchase     1004250  552651881
# 42421813  2019-10-31 21:05:24 UTC       view     1004250  552651881
# 42421953  2019-10-31 21:05:58 UTC       view     1004250  552651881

# %% [markdown]
# ------------------------------------------------------

# %% [markdown]
# # [RQ 2]- a
# # Plot the number of sold products per category

# %%
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv('2019-Oct.csv', header='infer',parse_dates=['event_time'],date_parser=pd.to_datetime)

# %%
dataset1=pd.read_csv('2019-Nov.csv', header='infer',parse_dates=['event_time'],date_parser=pd.to_datetime)

# %%
dataset2=pd.read_csv('2019-Dec.csv', header='infer',usecols=['event_type','category_code'])
dataset3=pd.read_csv('2020-Jan.csv', header='infer',usecols=['event_type','category_code'])
dataset4=pd.read_csv('2020-Feb.csv', header='infer',usecols=['event_type','category_code'])
dataset5=pd.read_csv('2020-Mar.csv', header='infer',usecols=['event_type','category_code'])
dataset6=pd.read_csv('2020-Apr.csv', header='infer',usecols=['event_type','category_code'])

# %% [markdown]
# ### CREATE DATAFRAMEs CALLED 'df_oct','df_nov' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of (respectively) october and november

# %%
#CREATE A DATAFRAME CALLED 'df_oct' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of october

a=dataset[dataset.event_type=='purchase'].groupby(dataset.category_code).category_code
c=0
ds=a.count()
df_oct = pd.DataFrame(columns=['category','number_of_sold_products'])
for i in a:
    name=i[0].split('.')
    df_oct.loc[c]=[name[0],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_nov' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of november

b=dataset1[dataset1.event_type=='purchase'].groupby(dataset1.category_code).category_code
c=0
ds1=b.count()
df_nov = pd.DataFrame(columns=['category','number_of_sold_products'])
for i in b:
    name=i[0].split('.')
    df_nov.loc[c]=[name[0],ds1[c]]
    c=c+1

# %% [markdown]
# ### CREATE DATAFRAMEs CALLED 'df_dec',  'df_jan',  'df_feb',  'df_mar',  'df_apr' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of (respectively) december 2019, january 2020, february 2020, march 2020, april 2020

# %%
#CREATE A DATAFRAME CALLED 'df_dec' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of december

d=dataset2[dataset2.event_type=='purchase'].groupby(dataset2.category_code).category_code
c=0
ds=d.count()
df_dec = pd.DataFrame(columns=['category','number_of_sold_products'])
for i in d:
    name=i[0].split('.')
    df_dec.loc[c]=[name[0],ds[c]]
    c=c+1
    
    
    
#CREATE A DATAFRAME CALLED 'df_jan' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of january

e=dataset3[dataset3.event_type=='purchase'].groupby(dataset3.category_code).category_code
c=0
ds=e.count()
df_jan = pd.DataFrame(columns=['category','number_of_sold_products'])
for i in e:
    name=i[0].split('.')
    df_jan.loc[c]=[name[0],ds[c]]
    c=c+1
    
    

#CREATE A DATAFRAME CALLED 'df_feb' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of february

f=dataset4[dataset4.event_type=='purchase'].groupby(dataset4.category_code).category_code
c=0
ds=f.count()
df_feb = pd.DataFrame(columns=['category','number_of_sold_products'])
for i in f:
    name=i[0].split('.')
    df_feb.loc[c]=[name[0],ds[c]]
    c=c+1
    
    
    
#CREATE A DATAFRAME CALLED 'df_mar' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of march

g=dataset5[dataset5.event_type=='purchase'].groupby(dataset5.category_code).category_code
c=0
ds=g.count()
df_mar = pd.DataFrame(columns=['category','number_of_sold_products'])
for i in g:
    name=i[0].split('.')
    df_mar.loc[c]=[name[0],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_apr' WITH ONLY 'CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of april

h=dataset6[dataset6.event_type=='purchase'].groupby(dataset6.category_code).category_code
c=0
ds=h.count()
df_apr = pd.DataFrame(columns=['category','number_of_sold_products'])
for i in h:
    name=i[0].split('.')
    df_apr.loc[c]=[name[0],ds[c]]
    c=c+1

# %%
fig=plt.figure(1)
plt.subplot(2,2,1)
df_oct.groupby('category').number_of_sold_products.sum().plot.bar(figsize=(20,7),fontsize = 10,\
                                                                 title='Categories of the most trending products of OCTOBER')


plt.subplot(2,2,3)
df_nov.groupby('category').number_of_sold_products.sum().plot.bar(figsize=(20,7), title='Categories of the most trending products of NOVEMBER',\
                                                                 fontsize = 10)
fig.tight_layout()

# %%
plt.figure()
df_dec.groupby('category').number_of_sold_products.sum().plot.bar(figsize=(13,4), title='Categories of the most trending products of DECEMBER',fontsize = 10)
plt.show()

# %%
plt.figure()
df_jan.groupby('category').number_of_sold_products.sum().plot.bar(figsize=(13,4), title='Categories of the most trending products of JANUARY',fontsize = 10)
plt.show()

# %%
plt.figure()
df_feb.groupby('category').number_of_sold_products.sum().plot.bar(figsize=(13,4), title='Categories of the most trending products of FEBRUARY',fontsize = 10)
plt.show()

# %%
plt.figure()
df_mar.groupby('category').number_of_sold_products.sum().plot.bar(figsize=(13,4), title='Categories of the most trending products of MARCH',fontsize = 10)
plt.show()

# %%
plt.figure()
df_apr.groupby('category').number_of_sold_products.sum().plot.bar(figsize=(13,4), title='Categories of the most trending products of APRIL',fontsize = 10)
plt.show()

# %% [markdown]
# # [RQ 2] - b
#
# # Plot the most visited subcategories
#
#
# ## We analize the most 25 visited Sub-categories;
#
# ## Because category's names are made by 'name1'.'name2 or by 'name1'.'name2'.'name3', we consider a sub-category the second name, so the name after the first dot('.').

# %%
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv('2019-Oct.csv', header='infer',usecols=['event_type','category_code'])
dataset1=pd.read_csv('2019-Nov.csv', header='infer',usecols=['event_type','category_code'])

# %%
dataset2=pd.read_csv('2019-Dec.csv', header='infer',usecols=['event_type','category_code'])
dataset3=pd.read_csv('2020-Jan.csv', header='infer',usecols=['event_type','category_code'])
dataset4=pd.read_csv('2020-Feb.csv', header='infer',usecols=['event_type','category_code'])
dataset5=pd.read_csv('2020-Mar.csv', header='infer',usecols=['event_type','category_code'])
dataset6=pd.read_csv('2020-Apr.csv', header='infer',usecols=['event_type','category_code'])

# %% [markdown]
# ### CREATE DATAFRAMEs CALLED 'df_oct','df_nov' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of (respectively) october and november

# %%
#CREATE A DATAFRAME CALLED 'df_oct' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of october

a=dataset[dataset.event_type=='view'].groupby(dataset.category_code).category_code
c=0
ds=a.count()
df_oct = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in a:
    name=i[0].split('.')
    df_oct.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_nov' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of november

b=dataset1[dataset1.event_type=='view'].groupby(dataset1.category_code).category_code
c=0
ds=b.count()
df_nov = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in b:
    name=i[0].split('.')
    df_nov.loc[c]=[name[1],ds[c]]
    c=c+1

# %% [markdown]
# ### CREATE DATAFRAMEs CALLED 'df_dec',  'df_jan',  'df_feb',  'df_mar',  'df_apr' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of (respectively) december 2019, january 2020, february 2020, march 2020, april 2020

# %%
    
#CREATE A DATAFRAME CALLED 'df_dec' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of december

d=dataset2[dataset2.event_type=='view'].groupby(dataset2.category_code).category_code
c=0
ds=d.count()
df_dec = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in d:
    name=i[0].split('.')
    df_dec.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
#CREATE A DATAFRAME CALLED 'df_jan' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of january

e=dataset3[dataset3.event_type=='view'].groupby(dataset3.category_code).category_code
c=0
ds=e.count()
df_jan = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in e:
    name=i[0].split('.')
    df_jan.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_feb' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of february

f=dataset4[dataset4.event_type=='view'].groupby(dataset4.category_code).category_code
c=0
ds=f.count()
df_feb = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in f:
    name=i[0].split('.')
    df_feb.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_mar' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of march

g=dataset5[dataset5.event_type=='view'].groupby(dataset5.category_code).category_code
c=0
ds=g.count()
df_mar = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in g:
    name=i[0].split('.')
    df_mar.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_apr' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of april

h=dataset6[dataset6.event_type=='view'].groupby(dataset6.category_code).category_code
c=0
ds=h.count()
df_apr = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in h:
    name=i[0].split('.')
    df_apr.loc[c]=[name[1],ds[c]]
    c=c+1

# %%
fig=plt.figure(1)
plt.subplot(2,2,1)
df_oct.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 10,\
                                                                 title='Most 25 visited Sub-categories of OCTOBER')


plt.subplot(2,2,3)
df_nov.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7), title='Most 25 visited Sub-categories of NOVEMBER',\
                                                                 fontsize = 10)
fig.tight_layout()

# %%
plt.figure()
df_dec.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of DECEMBER')
plt.show()

# %%
plt.figure()
df_jan.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of JANUARY')
plt.show()

# %%
plt.figure()
df_feb.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of FEBRUARY')
plt.show()

# %%
plt.figure()
df_mar.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of MARCH')
plt.show()

# %%
plt.figure()
df_apr.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of APRIL')
plt.show()

# %%
# [RQ 2] - b

# Plot the most visited subcategories
                                     
                                     
## We analize the most 25 visited Sub-categories;

## Because category's names are made by 'name1'.'name2 or by 'name1'.'name2'.'name3', we consider a sub-category the second name, so the name after the first dot('.').

import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv('2019-Oct.csv', header='infer',usecols=['event_type','category_code'])
dataset1=pd.read_csv('2019-Nov.csv', header='infer',usecols=['event_type','category_code'])

dataset2=pd.read_csv('2019-Dec.csv', header='infer',usecols=['event_type','category_code'])
dataset3=pd.read_csv('2020-Jan.csv', header='infer',usecols=['event_type','category_code'])
dataset4=pd.read_csv('2020-Feb.csv', header='infer',usecols=['event_type','category_code'])
dataset5=pd.read_csv('2020-Mar.csv', header='infer',usecols=['event_type','category_code'])
dataset6=pd.read_csv('2020-Apr.csv', header='infer',usecols=['event_type','category_code'])

### CREATE DATAFRAMEs CALLED 'df_oct','df_nov' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of (respectively) october and november

#CREATE A DATAFRAME CALLED 'df_oct' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of october

a=dataset[dataset.event_type=='view'].groupby(dataset.category_code).category_code
c=0
ds=a.count()
df_oct = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in a:
    name=i[0].split('.')
    df_oct.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_nov' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of november

b=dataset1[dataset1.event_type=='view'].groupby(dataset1.category_code).category_code
c=0
ds=b.count()
df_nov = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in b:
    name=i[0].split('.')
    df_nov.loc[c]=[name[1],ds[c]]
    c=c+1
    

### CREATE DATAFRAMEs CALLED 'df_dec',  'df_jan',  'df_feb',  'df_mar',  'df_apr' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF SOLD PRODUCTS' of (respectively) december 2019, january 2020, february 2020, march 2020, april 2020

    
#CREATE A DATAFRAME CALLED 'df_dec' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of december

d=dataset2[dataset2.event_type=='view'].groupby(dataset2.category_code).category_code
c=0
ds=d.count()
df_dec = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in d:
    name=i[0].split('.')
    df_dec.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
#CREATE A DATAFRAME CALLED 'df_jan' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of january

e=dataset3[dataset3.event_type=='view'].groupby(dataset3.category_code).category_code
c=0
ds=e.count()
df_jan = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in e:
    name=i[0].split('.')
    df_jan.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_feb' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of february

f=dataset4[dataset4.event_type=='view'].groupby(dataset4.category_code).category_code
c=0
ds=f.count()
df_feb = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in f:
    name=i[0].split('.')
    df_feb.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_mar' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of march

g=dataset5[dataset5.event_type=='view'].groupby(dataset5.category_code).category_code
c=0
ds=g.count()
df_mar = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in g:
    name=i[0].split('.')
    df_mar.loc[c]=[name[1],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_apr' WITH ONLY 'SUB-CATEGORIES' AND 'NUMBER OF VIEWS' of april

h=dataset6[dataset6.event_type=='view'].groupby(dataset6.category_code).category_code
c=0
ds=h.count()
df_apr = pd.DataFrame(columns=['sub_category','number_of_views'])
for i in h:
    name=i[0].split('.')
    df_apr.loc[c]=[name[1],ds[c]]
    c=c+1

    
    
    


fig=plt.figure(1)
plt.subplot(2,2,1)
df_oct.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 10,\
                                                                 title='Most 25 visited Sub-categories of OCTOBER')


plt.subplot(2,2,3)
df_nov.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7), title='Most 25 visited Sub-categories of NOVEMBER',\
                                                                 fontsize = 10)
fig.tight_layout()

plt.figure()
df_dec.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of DECEMBER')
plt.show()

plt.figure()
df_jan.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of JANUARY')
plt.show()

plt.figure()
df_feb.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of FEBRUARY')
plt.show()

plt.figure()
df_mar.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of MARCH')
plt.show()

plt.figure()
df_apr.groupby('sub_category').number_of_views.sum().sort_values(ascending=False).head(25).plot.bar(figsize=(25,7),fontsize = 14,\
                                                                 title='Most 25 visited Sub-categories of APRIL')
plt.show()

# %% [markdown]
# # [RQ 2] - c
# # What are the 10 most sold products per category?

# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv('2019-Oct.csv', header='infer',usecols=['event_type','category_code'])
dataset1=pd.read_csv('2019-Nov.csv', header='infer',usecols=['event_type','category_code'])
dataset2=pd.read_csv('2019-Dec.csv', header='infer',usecols=['event_type','category_code'])
dataset3=pd.read_csv('2020-Jan.csv', header='infer',usecols=['event_type','category_code'])
dataset4=pd.read_csv('2020-Feb.csv', header='infer',usecols=['event_type','category_code'])
dataset5=pd.read_csv('2020-Mar.csv', header='infer',usecols=['event_type','category_code'])
dataset6=pd.read_csv('2020-Apr.csv', header='infer',usecols=['event_type','category_code'])

# %%
#CREATE A DATAFRAME CALLED 'df_oct' WITH ONLY 'CATEGORIES','PRODUCT_TYPE' AND 'NUMBER OF SOLD PRODUCTS' of october

a=dataset[dataset.event_type=='purchase'].groupby(dataset.category_code).category_code
c=0
ds=a.count()
df_oct = pd.DataFrame(columns=['category','product_type','number_of_sold_products'])
for i in a:
    name=i[0].split('.')
    df_oct.loc[c]=[name[0],name[-1],ds[c]]
    c=c+1
    
    
    
    
#CREATE A DATAFRAME CALLED 'df_nov' WITH ONLY 'CATEGORIES','PRODUCT_TYPE' AND 'NUMBER OF SOLD PRODUCTS' of november

b=dataset1[dataset1.event_type=='purchase'].groupby(dataset1.category_code).category_code
c=0
ds1=b.count()
df_nov = pd.DataFrame(columns=['category','product_type','number_of_sold_products'])
for i in b:
    name=i[0].split('.')
    df_nov.loc[c]=[name[0],name[-1],ds1[c]]
    c=c+1
    
    
    
#CREATE A DATAFRAME CALLED 'df_dec' WITH ONLY 'CATEGORIES','PRODUCT_TYPE' AND 'NUMBER OF SOLD PRODUCTS' of december

d=dataset2[dataset2.event_type=='purchase'].groupby(dataset2.category_code).category_code
c=0
ds1=d.count()
df_dec = pd.DataFrame(columns=['category','product_type','number_of_sold_products'])
for i in d:
    name=i[0].split('.')
    df_dec.loc[c]=[name[0],name[-1],ds1[c]]
    c=c+1
    
    

#CREATE A DATAFRAME CALLED 'df_jan' WITH ONLY 'CATEGORIES','PRODUCT_TYPE' AND 'NUMBER OF SOLD PRODUCTS' of january

e=dataset3[dataset3.event_type=='purchase'].groupby(dataset3.category_code).category_code
c=0
ds1=e.count()
df_jan = pd.DataFrame(columns=['category','product_type','number_of_sold_products'])
for i in e:
    name=i[0].split('.')
    df_jan.loc[c]=[name[0],name[-1],ds1[c]]
    c=c+1
    
    


#CREATE A DATAFRAME CALLED 'df_feb' WITH ONLY 'CATEGORIES','PRODUCT_TYPE' AND 'NUMBER OF SOLD PRODUCTS' of february

f=dataset4[dataset4.event_type=='purchase'].groupby(dataset4.category_code).category_code
c=0
ds1=f.count()
df_feb = pd.DataFrame(columns=['category','product_type','number_of_sold_products'])
for i in f:
    name=i[0].split('.')
    df_feb.loc[c]=[name[0],name[-1],ds1[c]]
    c=c+1
    
    
    

#CREATE A DATAFRAME CALLED 'df_mar' WITH ONLY 'CATEGORIES','PRODUCT_TYPE' AND 'NUMBER OF SOLD PRODUCTS' of march

g=dataset5[dataset5.event_type=='purchase'].groupby(dataset5.category_code).category_code
c=0
ds1=g.count()
df_mar = pd.DataFrame(columns=['category','product_type','number_of_sold_products'])
for i in g:
    name=i[0].split('.')
    df_mar.loc[c]=[name[0],name[-1],ds1[c]]
    c=c+1
    
    
    
#CREATE A DATAFRAME CALLED 'df_apr' WITH ONLY 'CATEGORIES','PRODUCT_TYPE' AND 'NUMBER OF SOLD PRODUCTS' of april

h=dataset6[dataset6.event_type=='purchase'].groupby(dataset6.category_code).category_code
c=0
ds1=h.count()
df_apr = pd.DataFrame(columns=['category','product_type','number_of_sold_products'])
for i in h:
    name=i[0].split('.')
    df_apr.loc[c]=[name[0],name[-1],ds1[c]]
    c=c+1

# %% [markdown]
# ### What are the 10 most sold products per category of OCTOBER?

# %%
pd.set_option('display.max_rows', 400)
aa=df_oct.groupby('category').apply(lambda x: x.sort_values(by='number_of_sold_products',ascending=False).head(10))
aa
# Out:
#                       category   product_type number_of_sold_products
# category
# accessories  0     accessories            bag                    1253
#              2     accessories         wallet                     310
#              1     accessories       umbrella                      24
# apparel      11        apparel          shoes                    4255
#              13        apparel           keds                    2711
#              4         apparel        costume                     489
#              7         apparel          jeans                     140
#              22        apparel      underwear                      97
#              14        apparel      moccasins                      72
#              21        apparel         tshirt                      58
#              10        apparel          shirt                      38
#              15        apparel        sandals                      25
# ...

# %% [markdown]
# ### What are the 10 most sold products per category of **NOVEMBER**?

# %%
bb=df_nov.groupby('category').apply(lambda x: x.sort_values(by='number_of_sold_products',ascending=False).head(10))
bb
# Out:
#                       category   product_type number_of_sold_products
# category
# accessories  0     accessories            bag                    1762
#              2     accessories         wallet                     366
#              1     accessories       umbrella                      26
# apparel      11        apparel          shoes                   10140
#              13        apparel           keds                    2270
#              4         apparel        costume                     879
#              7         apparel          jeans                     169
#              10        apparel          shirt                     122
#              5         apparel          dress                     112
#              22        apparel         tshirt                      93
#              23        apparel      underwear                      84
#              8         apparel         jumper                      82
# ...

# %% [markdown]
# ### What are the 10 most sold products per category of DECEMBER?

# %%
cc=df_dec.groupby('category').apply(lambda x: x.sort_values(by='number_of_sold_products',ascending=False).head(10))
cc
# Out:
#                       category    product_type number_of_sold_products
# category
# accessories  0     accessories             bag                    3939
#              2     accessories          wallet                    3169
#              1     accessories        umbrella                     238
# apparel      13        apparel           shoes                   38456
#              18        apparel         sandals                   16271
#              19        apparel         slipons                   11985
#              16        apparel            keds                    8529
#              11        apparel           scarf                    5210
#              4         apparel         costume                    5191
#              21        apparel          shorts                    3831
#              12        apparel           shirt                    3793
#              26        apparel       underwear                    3670
# ...

# %% [markdown]
# ### What are the 10 most sold products per category of JANUARY?

# %%
dd=df_jan.groupby('category').apply(lambda x: x.sort_values(by='number_of_sold_products',ascending=False).head(10))
dd
# Out:
#                       category    product_type number_of_sold_products
# category
# accessories  0     accessories             bag                    3269
#              2     accessories          wallet                    2023
#              1     accessories        umbrella                     236
# apparel      13        apparel           shoes                   23875
#              19        apparel         slipons                    7024
#              18        apparel         sandals                    6275
#              16        apparel            keds                    5363
#              4         apparel         costume                    4117
#              12        apparel           shirt                    3223
#              11        apparel           scarf                    2953
#              21        apparel          shorts                    2622
#              24        apparel        trousers                    2297
# ...

# %% [markdown]
# ### What are the 10 most sold products per category of FEBRUARY?

# %%
ee=df_feb.groupby('category').apply(lambda x: x.sort_values(by='number_of_sold_products',ascending=False).head(10))
ee
# Out:
#                       category    product_type number_of_sold_products
# category
# accessories  0     accessories             bag                    4777
#              2     accessories          wallet                    2403
#              1     accessories        umbrella                     251
# apparel      13        apparel           shoes                   30326
#              18        apparel         sandals                   12332
#              19        apparel         slipons                   10590
#              16        apparel            keds                    7863
#              24        apparel        trousers                    4884
#              4         apparel         costume                    4835
#              12        apparel           shirt                    4194
#              11        apparel           scarf                    4057
#              21        apparel          shorts                    3989
# ...

# %% [markdown]
# ### What are the 10 most sold products per category of MARCH?

# %%
ff=df_mar.groupby('category').apply(lambda x: x.sort_values(by='number_of_sold_products',ascending=False).head(10))
ff
# Out:
#                       category    product_type number_of_sold_products
# category
# accessories  0     accessories             bag                    4653
#              2     accessories          wallet                    1509
#              1     accessories        umbrella                     204
# apparel      12        apparel           shoes                   23497
#              17        apparel         sandals                   10377
#              18        apparel         slipons                   10351
#              15        apparel            keds                    6202
#              23        apparel        trousers                    5654
#              10        apparel           scarf                    4275
#              3         apparel         costume                    4006
#              11        apparel           shirt                    3844
#              20        apparel          shorts                    3618
# ...

# %% [markdown]
# ### What are the 10 most sold products per category of APRIL?

# %%
gg=df_apr.groupby('category').apply(lambda x: x.sort_values(by='number_of_sold_products',ascending=False).head(10))
gg
# Out:
#                       category     product_type number_of_sold_products
# category
# accessories  0     accessories              bag                    5493
#              2     accessories           wallet                     619
#              1     accessories         umbrella                     330
# apparel      12        apparel            shoes                   22192
#              18        apparel          slipons                   11285
#              17        apparel          sandals                    7337
#              15        apparel             keds                    6481
#              23        apparel         trousers                    5202
#              10        apparel            scarf                    5074
#              11        apparel            shirt                    4730
#              25        apparel        underwear                    3611
#              3         apparel          costume                    3509
# ...

# %% [markdown]
# -------------------------------------------------------

# %% [markdown]
# # [RQ3] For each category, what’s the brand whose prices are higher on average?

# %% [markdown]
# #### Write a function that asks the user a category in input and returns a plot indicating the average price of the products sold by the brand.

# %% [markdown]
# For this answer we consider as **category** the name before the . in the category code.
#
# So, first of all we clean up our data, dropping all the _na_ in the **category_code** and **brand** columns.
#
# Then, we select only the sold products.
#
# Finally we wrote a function that accepts as input the name of a **category** such as _accessories, electronics, furniture_ and plots the average price of the most expensive brands, i.e. the brands with the highest average price of the products sold in the year, sorted by the average price.
#
# Below, as example, we see the average prices of brands belonging to the category *electronics*.

# %%
dataframes = [pd.read_csv(file,usecols=['category_code','brand','price','event_type'], nrows=100000) for file in filenames]

# %%
salesframes = [df[df.event_type=='purchase'][['category_code','brand','price']].dropna() for df in dataframes]

# %%
saleframes = [df.assign(category=(df['category_code'].apply(lambda x: x.split('.')[0])))[['category','brand','price']] for df in salesframes]

# %%
all_months_frame = pd.concat(saleframes)

# %% [markdown]
# Below we see the original dataset structure, with the **category_code** esxpressed as *category.subcategory*:

# %%
salesframes[0].head()
# Out:
#                    category_code    brand   price
# 162       electronics.smartphone  samsung  130.76
# 308       electronics.smartphone    apple  642.69
# 442    furniture.bathroom.toilet  santeri   54.42
# 574  electronics.audio.headphone    apple  189.91
# 603  electronics.audio.headphone    apple  161.98

# %% [markdown]
# We extract the **category** from the category code:

# %%
all_months_frame.head()
# Out:
#         category    brand   price
# 162  electronics  samsung  130.76
# 308  electronics    apple  642.69
# 442    furniture  santeri   54.42
# 574  electronics    apple  189.91
# 603  electronics    apple  161.98

# %%
def plot_brand_highest_price(category, data):
    fig=plt.figure(figsize=(21,9))
    plot=sns.barplot(x='brand',y='price',data= data.nlargest(20,'price'))
    for p in plot.patches:
        plot.annotate(format(p.get_height(), ',.0f'),
                      (p.get_x()+p.get_width() /2.,p.get_height() ),
                      ha = 'center',
                      va = 'center', 
                      xytext = (0, 12), 
                      textcoords = 'offset points')
    plt.title('Average price for each brand of the category ' + category, size=18)
    plt.xlabel('Brands',size=12)
    plt.ylabel('Average price  [$]',size=12)

# %%
def brand_highest_price():
    category_target = input('insert a category:')
    target_frame = all_months_frame[all_months_frame.category == category_target]
    if target_frame.empty:
        print(category_target, 'not found')
        return
    g = target_frame.groupby('brand').agg({'price':'mean'}).reset_index()
    plot_brand_highest_price(category_target, g)

# %%
brand_highest_price()
# Out:
# insert a category:electronics

# %% [markdown]
# ## Find, for each category, the brand with the highest average price. Return all the results in ascending order by price

# %%
all_months_frame.groupby(['category', 'brand']).agg({'price':'mean'})['price']\
.groupby('category', group_keys=False)\
.apply(lambda x: x.sort_values(ascending=False).head(1)).reset_index().sort_values(by='price', ascending=False)
# Out:
#         category       brand     price
# 8      furniture        sony  2265.150
# 7    electronics      garmin  1745.220
# 2     appliances         krk  1603.130
# 4      computers       apple  1352.420
# 11         sport     sportop  1171.200
# 5   construction         dji   910.960
# 1        apparel   ostamebel   765.785
# 3           auto       alkor   690.630
# 0    accessories         brw   592.290
# 9           kids    marshall   438.360
# 12    stationery   microsoft   257.380
# 10      medicine  muscletech    62.420
# 6   country_yard        sony    39.995

# %% [markdown]
# ---------------------------------------------------

# %% [markdown]
# # [RQ4] How much does each brand earn per month?
#
# ### Write a function that given the name of a brand in input returns, for each month, its profit.

# %% [markdown]
# To find out the profits of each brand, first of all, we select only the purchases in the datasets for each month.
#
# Then, we define a function that, given the name of a brand, calculates its profits in each monthly dateset.
#
# For example, we call the fuction with the brand _Samsung._

# %%
periods = {0:'October - November',1:'November - December',2:'December - January',3:'January - Febrary',
           4:'Febrary - March',5:'March - April'}

# %%
dataframes = [pd.read_csv(file,usecols=['brand', 'price','event_type']) for file in filenames]

# %%
dataframes = [df.dropna() for df in dataframes]

# %%
purchase_dataframe = [df[df.event_type == 'purchase'][['brand', 'price']] for df in dataframes]

# %%
def profit_per_month(brand_target,dataframes):
    profits = [df[df.brand==brand_target].price.sum() for df in dataframes]
    return profits

# %%
def brand_profit_per_month(brand_target,dataframes):
    profits = profit_per_month(brand_target,purchase_dataframe)
    print('The profits for the brand: "'+ brand_target +'" was:')
    print(f"{'Month' : <12}{'Profit $' : <12}")
    for i in range(len(profits)):
        print(f"{months[i] : <12}{round(profits[i],2) : <12}")

# %%
brand_profit_per_month('samsung',purchase_dataframe)
# Out:
# The profits for the brand: "samsung" was:
# Month       Profit $
# October     46407532.61
# November    54869880.87
# December    71858811.05
# January     55786627.06
# Febrary     74269250.38
# March       65440260.34
# April       56791598.49

# %% [markdown]
# ## Find the top 3 brands that have suffered the biggest losses in earnings between one month and the next

# %% [markdown]
# For this purpose we find the profits of each brand in each month.
#
# In the event that a brand is not present in a montly dataset we assume a profit equal to 0 in that month.
#
# In particular, for each brand we find out its biggest losses between one month and the next and the relatives months.
#
# In the end, we select the 3 biggest losses.

# %%
all_brands_frames = pd.concat([df['brand'] for df in purchase_dataframe]).drop_duplicates().to_frame()

# %%
all_brands_frames.head()
# Out:
#        brand
# 162  samsung
# 308    apple
# 379   xiaomi
# 442  santeri
# 672    oasis

# %%
def max_loss(brand_name,purchase_dataframe):
    brand_name = brand_name['brand']
    profits = profit_per_month(brand_name,purchase_dataframe)
    loss = []
    for i in range((len(profits) - 1)):   
        if (profits[i] == 0):
            loss.append(round(((profits[i + 1] - profits[i]))*100,2))
        else:
            loss.append(round(((profits[i + 1] - profits[i])/profits[i])*100,2))
    return [min(loss),loss.index(min(loss))]

# %%
all_brands_frames[['max_loss','period']] = all_brands_frames.apply(lambda x: max_loss(x,purchase_dataframe),axis=1, result_type='expand')

# %% [markdown]
# Below we see for a portion of the brand set the largest loss of earnings (**max_loss**) compared to the previous month as a percentage,
#
#  with the period to which it refers, where period 0 means November-October,period 1 Dicember-November and so on until
#
#  period 5 that means April-March.

# %%
all_brands_frames.head()
# Out:
#        brand  max_loss  period
# 162  samsung    -22.37     2.0
# 308    apple    -47.43     5.0
# 379   xiaomi    -29.05     4.0
# 442  santeri    -63.42     5.0
# 672    oasis    -57.84     2.0

# %%
three_big_loss = all_brands_frames.nsmallest(3,'max_loss')
three_big_loss['period'] = three_big_loss['period'].apply(lambda x : periods[x])

# %% [markdown]
# Finaly we see the 3 biggest losses and the relative periods:

# %%
three_big_loss
# Out:
#          brand  max_loss              period
# 2885   ersport    -100.0       March - April
# 16339      sly    -100.0  October - November
# 27078       ea    -100.0  December - January

# %% [markdown]
# So *ersport*, *sly* and *ea* suffered a 100% loss of earnings respectively between March and April,October and November,December and January. This means that in the second months it did not gain anything.

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# # [RQ5] In what part of the day is your store most visited?
#
# ### We want to know which day of the week there are more visitors.
#
# For this question we will find the average number of visitors per hour for each day of the week.
#
# For "visitor" we look at the **user_id**, beacause in each dataset each visitor is identified by a unique user_id.
#
# We used this to get the number unique visitors in each day.
#
# Finally, starting from the absolute number of visitors per day we calculate the hourly average.

# %%
# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
#dataset used
filenames = ['2019-Oct.csv', '2019-Nov.csv','2019-Dec.csv','2020-Jan.csv','2020-Feb.csv','2020-Mar.csv','2020-Apr.csv']

# %%
day = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}

# %%
dataframes = [pd.read_csv(file,usecols=['event_time', 'user_id'],parse_dates=['event_time'],date_parser=pd.to_datetime) for file in filenames]

# %%
week_frame = [df.groupby([df.event_time.dt.weekday]).user_id.nunique().reset_index(name='visitors') for df in dataframes]

# %% [markdown]
# First, we find the absolute number of vistors in each day of the week, for each montly dataframe.
#
# Below we see October as example:

# %%
october = week_frame[0]
october['event_time'] = october['event_time'].apply(lambda x : day[x])
october
# Out:
#   event_time  visitors
# 0     Monday    707787
# 1    Tuesday    889037
# 2  Wednesday    878913
# 3   Thursday    836989
# 4     Friday    762843
# 5   Saturday    713040
# 6     Sunday    737350

# %%
year_frame = sum(week_frame)

# %% [markdown]
# Then we sum all the months:

# %%
year_frame['event_time'] = year_frame['event_time'].apply(lambda x : day[x/7])
year_frame
# Out:
#   event_time  visitors
# 0     Monday   7439731
# 1    Tuesday   7490929
# 2  Wednesday   7527666
# 3   Thursday   7411765
# 4     Friday   7224134
# 5   Saturday   7191362
# 6     Sunday   7358128

# %%
year_frame['visitors'] = round(year_frame['visitors']/24)

# %%
year_frame.columns = ['day of week', 'hourly average visitors']

# %% [markdown]
# In the end, we compute the hourly average number of visitors:

# %%
year_frame
# Out:
#   day of week  hourly average visitors
# 0      Monday                 309989.0
# 1     Tuesday                 312122.0
# 2   Wednesday                 313653.0
# 3    Thursday                 308824.0
# 4      Friday                 301006.0
# 5    Saturday                 299640.0
# 6      Sunday                 306589.0

# %%
def plot(frame):
    f = plt.figure()
    plt.xticks(range(0,7),frame['day of week'])
    plt.ylabel("hourly average")
    plt.xlabel("day of week")
    plt.title("Hourly average of visitors in each day of the week")
    plt.plot(range(0,7), frame['hourly average visitors'], '-o', markersize=10, color='crimson')
    plt.grid(color ='lightgray', linestyle = '-.')
    f.set_figwidth(14)
    f.set_figheight(5)

# %% [markdown]
# We see how the number of e-commerce visitors decreases over the weekend and in maximum in the in the first days of the week:

# %%
plot(year_frame)

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# # [RQ 6]
# # Find the overall conversion rate of your store

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv('2019-Oct.csv', header='infer')
dataset1=pd.read_csv('2019-Nov.csv', header='infer')

# %%
dataset2=pd.read_csv('2019-Dec.csv', header='infer')
dataset3=pd.read_csv('2020-Jan.csv', header='infer')
dataset4=pd.read_csv('2020-Feb.csv', header='infer')
dataset5=pd.read_csv('2020-Mar.csv', header='infer')
dataset6=pd.read_csv('2020-Apr.csv', header='infer')

# %%
num_of_purchase_oct=dataset[dataset.event_type=='purchase'].event_type.count()
num_of_visit_oct=dataset[dataset.event_type=='view'].event_type.count()

# %%
num_of_purchase_nov=dataset1[dataset1.event_type=='purchase'].event_type.count()
num_of_visit_nov=dataset1[dataset1.event_type=='view'].event_type.count()

# %%
num_of_purchase_dec=dataset2[dataset2.event_type=='purchase'].event_type.count()
num_of_visit_dec=dataset2[dataset2.event_type=='view'].event_type.count()

# %%
num_of_purchase_jan=dataset3[dataset3.event_type=='purchase'].event_type.count()
num_of_visit_jan=dataset3[dataset3.event_type=='view'].event_type.count()

# %%
num_of_purchase_feb=dataset4[dataset4.event_type=='purchase'].event_type.count()
num_of_visit_feb=dataset4[dataset4.event_type=='view'].event_type.count()

# %%
num_of_purchase_mar=dataset5[dataset5.event_type=='purchase'].event_type.count()
num_of_visit_mar=dataset5[dataset5.event_type=='view'].event_type.count()

# %%
num_of_purchase_apr=dataset6[dataset6.event_type=='purchase'].event_type.count()
num_of_visit_apr=dataset6[dataset6.event_type=='view'].event_type.count()

# %% [markdown]
# ### conversion rate of OCTOBER:

# %%
conversion_rate_oct=(num_of_purchase_oct/num_of_visit_oct)
conversion_rate_oct
# Out:
# 0.01821628121591493

# %% [markdown]
# ### conversion rate of NOVEMBER:

# %%
conversion_rate_nov=(num_of_purchase_nov/num_of_visit_nov)
conversion_rate_nov
# Out:
# 0.01442723602813325

# %% [markdown]
# ### conversion rate of DECEMBER:

# %%
conversion_rate_dec=(num_of_purchase_dec/num_of_visit_dec)
conversion_rate_dec
# Out:
# 0.018449286569996504

# %% [markdown]
# ### conversion rate of JANUARY:

# %%
conversion_rate_jan=(num_of_purchase_jan/num_of_visit_jan)
conversion_rate_jan
# Out:
# 0.015907687415991207

# %% [markdown]
# ### conversion rate of  FEBRUARY:

# %%
conversion_rate_feb=(num_of_purchase_feb/num_of_visit_feb)
conversion_rate_feb
# Out:
# 0.023428176267763837

# %% [markdown]
# ### conversion rate of  MARCH:

# %%
conversion_rate_mar=(num_of_purchase_mar/num_of_visit_mar)
conversion_rate_mar
# Out:
# 0.019579272601332125

# %% [markdown]
# ## conversion rate of  APRIL:

# %%
conversion_rate_apr=(num_of_purchase_apr/num_of_visit_apr)
conversion_rate_apr
# Out:
# 0.015504384817317548

# %% [markdown]
# ### OVERALL CONVERSION RATE OF THE STORE (OCTOBER+NOVEMBER+DECEMBER+JANUARY+FEBRUARY+MARCH+APRIL):

# %%
num_p=num_of_purchase_oct+num_of_purchase_nov+num_of_purchase_dec+num_of_purchase_jan+num_of_purchase_mar+num_of_purchase_apr
num_v=num_of_visit_oct+num_of_visit_nov+num_of_visit_dec+num_of_visit_jan+num_of_visit_feb+num_of_visit_mar+num_of_visit_apr
overall_conversion_rate=(num_p)/(num_v)
overall_conversion_rate
# Out:
# 0.01464311637189809

# %% [markdown]
# # [RQ 6]
# # "Plot the number of purchases of each category"
#
#
#
# ## Because of the huge number of different Category, we added, for each month, also the plot of the same month but with less categories, to have a more ordered plot and to understand it better.

# %%
a_oct=dataset[dataset.event_type=='purchase'].groupby('category_id').event_type.count()
a_oct.plot.bar(figsize = (35, 15))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - october', fontsize = 40)
plt.show()

# %%
a_oct.head(100).plot.bar(figsize = (35, 7))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - october - first 100 categories', fontsize = 40)
plt.show()

# %%
a_nov=dataset1[dataset1.event_type=='purchase'].groupby('category_id').event_type.count()
a_nov.plot.bar(figsize = (35, 15))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - november', fontsize = 40)
plt.show()

# %%
a_nov.head(100).plot.bar(figsize = (35, 7))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - november - first 100 categories', fontsize = 40)
plt.show()

# %%
a_dec=dataset2[dataset2.event_type=='purchase'].groupby('category_id').event_type.count()
a_dec.head(100).plot.bar(figsize = (35, 7))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - december - first 100 categories', fontsize = 40)
plt.show()

# %%
a_jan=dataset3[dataset3.event_type=='purchase'].groupby('category_id').event_type.count()
a_jan.head(100).plot.bar(figsize = (35, 7))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - january - first 100 categories', fontsize = 40)
plt.show()

# %%
a_feb=dataset4[dataset4.event_type=='purchase'].groupby('category_id').event_type.count()
a_feb.head(100).plot.bar(figsize = (35, 7))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - february - first 100 categories', fontsize = 40)
plt.show()

# %%
a_mar=dataset5[dataset5.event_type=='purchase'].groupby('category_id').event_type.count()
a_mar.head(100).plot.bar(figsize = (35, 7))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - march - first 100 categories', fontsize = 40)
plt.show()

# %%
a_apr=dataset6[dataset6.event_type=='purchase'].groupby('category_id').event_type.count()
a_apr.head(100).plot.bar(figsize = (35, 7))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - april - first 100 categories', fontsize = 40)
plt.show()

# %%
tot=pd.concat([dataset,dataset1])
a=tot[tot.event_type=='purchase'].groupby('category_id').event_type.count().to_frame(name = 'number of purchase')
a.plot.bar(figsize = (35, 15))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - october+november', fontsize = 35)
plt.show()

# %%
a.head(100).plot.bar(figsize = (35, 7))
plt.title('NUMBER OF PURCHASES OF EACH CATEGORY - october+november - first 100 categories', fontsize = 35)
plt.show()

# %%
b=tot[tot.event_type=='view'].groupby('category_id').event_type.count().to_frame(name = 'number of visit')
r=pd.concat([a,b],join='inner',axis=1)

# %%
r['conversion_rate']=(r['number of purchase']/r['number of visit'])

# %% [markdown]
#                                 CONVERSATION RATE OF EACH CATEGORY IN DECREASING ORDER:

# %%
r.conversion_rate.sort_values(ascending=False).to_frame(name = 'conversion rate (october+november)')
# Out:
#                      conversion rate (october+november)
# category_id
# 2053013555690602915                            0.052632
# 2053013556344914381                            0.029664
# 2053013555631882655                            0.028315
# 2053013560388223675                            0.027778
# 2053013553375346967                            0.027570
# ...                                                 ...
# 2110937221648352149                            0.000646
# 2091727629378912491                            0.000402
# 2125931803410694331                            0.000340
# 2090971680431145002                            0.000320
# 2125175570022007765                            0.000069
#
# [636 rows x 1 columns]

# %% [markdown]
# # [RQ 7]
# # "most of your business, around 80%, likely comes from about 20% of your customers"
#
#
# ## To prove that, we show that the amount of money spent by the 20% of users (considering that in this percentage there are the users WHO SPENT MORE), is roughly egual to the 80% of the Total Profit.

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv('2019-Oct.csv', header='infer',usecols=['event_type','user_id','price'])
dataset1=pd.read_csv('2019-Nov.csv', header='infer',usecols=['event_type','user_id','price'])
dataset2=pd.read_csv('2019-Dec.csv', header='infer',usecols=['event_type','user_id','price'])
dataset3=pd.read_csv('2020-Jan.csv', header='infer',usecols=['event_type','user_id','price'])
dataset4=pd.read_csv('2020-Feb.csv', header='infer',usecols=['event_type','user_id','price'])
dataset5=pd.read_csv('2020-Mar.csv', header='infer',usecols=['event_type','user_id','price'])
dataset6=pd.read_csv('2020-Apr.csv', header='infer',usecols=['event_type','user_id','price'])

# %%
a=dataset[dataset.event_type=='purchase'].groupby('user_id').price.sum().to_frame(name = 'money_spent(oct)')
b=dataset1[dataset1.event_type=='purchase'].groupby('user_id').price.sum().to_frame(name = 'money_spent(nov)')
c=dataset2[dataset2.event_type=='purchase'].groupby('user_id').price.sum().to_frame(name = 'money_spent(dec)')
d=dataset3[dataset3.event_type=='purchase'].groupby('user_id').price.sum().to_frame(name = 'money_spent(jan)')
e=dataset4[dataset4.event_type=='purchase'].groupby('user_id').price.sum().to_frame(name = 'money_spent(feb)')
f=dataset5[dataset5.event_type=='purchase'].groupby('user_id').price.sum().to_frame(name = 'money_spent(mar)')
g=dataset6[dataset6.event_type=='purchase'].groupby('user_id').price.sum().to_frame(name = 'money_spent(apr)')

# %%
r=pd.concat([a,b,c,d,e,f,g], axis=1)

# %%
r['total_money_spent']=r.sum(axis=1)

# %% [markdown]
# ### Here is shown how much every user_id spent between OCTOBER 2019 and APRIL 2020, ordered from the one who spent more, to the one who spent less

# %%
r1=r.total_money_spent.sort_values(ascending=False).to_frame(name = 'total_money_spent')
r1
# Out:
#            total_money_spent
# user_id
# 553431815          790120.94
# 549109608          750149.97
# 569333570          689273.09
# 513230794          647798.65
# 595104624          605792.74
# ...                      ...
# 601133752               0.54
# 575831066               0.53
# 648016884               0.49
# 648343179               0.42
# 646832123               0.31
#
# [2064899 rows x 1 columns]

# %% [markdown]
# ### How many users (ordered from the one who spent more, to the one who spent less) are the 20% of the total number of users who bought something?

# %%
twenty_n_of_users=(20*len(r1.index))//100
twenty_n_of_users
# Out:
# 412979

# %% [markdown]
# ### Total amount of money spent by the 20% of the users (ordered from the one who spent more, to the one who spent less):

# %%
f=float(r1[:twenty_n_of_users].sum())
f
# Out:
# 1533846296.5700002

# %% [markdown]
# ### The total profit is:

# %%
summ=r1.sum()
float(summ)
# Out:
# 2057447227.860001

# %% [markdown]
# ### The 80% of the profit is:

# %%
float((80*summ)//100)
# Out:
# 1645957782.0

# %%
perc=round((f*100)/summ,2)

# %% [markdown]
# ## In the end, let's calculate what is the percentage, considering the total                                                                                profit, of money spent by the 20% of the users who spent more

# %%
print('In fact, the total amount of money spent by the 20% of the users (users WHO SPENT MORE), is equal to the '+str(perc[0])+'% of the Total Profit!!!')
# Out:
# In fact, the total amount of money spent by the 20% of the users (users WHO SPENT MORE), is equal to the 74.55% of the Total Profit!!!
